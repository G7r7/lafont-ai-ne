# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

# %%
batch_size = 64  # Batch size for training.
epochs = 100  # Number of epochs to train for.
latent_dim = 256  # Latent dimensionality of the encoding space.
num_samples = 142000  # Number of samples to train on.
# Path to the data txt file on disk.
data_path = "/lexique/lexique.csv"

# %%
# Vectorize the data.
input_texts = []
target_texts = []
input_characters = set()
target_characters = set()
with open(data_path, "r", encoding="utf-8") as f:
    lines = f.read().split("\n")
for line in lines[: min(num_samples, len(lines) - 1)]:
    input_text, target_text = line.split(",")
    # We use "," as the "start sequence" character
    # for the targets, and "\n" as "end sequence" character.
    target_text = "," + target_text + "\n"
    input_texts.append(input_text)
    target_texts.append(target_text)
    for char in input_text:
        if char not in input_characters:
            input_characters.add(char)
    for char in target_text:
        if char not in target_characters:
            target_characters.add(char)

input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)
max_encoder_seq_length = max([len(txt) for txt in input_texts])
max_decoder_seq_length = max([len(txt) for txt in target_texts])

print("Number of samples:", len(input_texts))
print("Number of unique input tokens:", num_encoder_tokens)
print("Number of unique output tokens:", num_decoder_tokens)
print("Max sequence length for inputs:", max_encoder_seq_length)
print("Max sequence length for outputs:", max_decoder_seq_length)

input_token_index = dict([(char, i) for i, char in enumerate(input_characters)])
target_token_index = dict([(char, i) for i, char in enumerate(target_characters)])

encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length, num_encoder_tokens), dtype="float32"
)
decoder_input_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens), dtype="float32"
)
decoder_target_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens), dtype="float32"
)

for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.0
    encoder_input_data[i, t + 1 :, input_token_index[" "]] = 1.0
    for t, char in enumerate(target_text):
        # decoder_target_data is ahead of decoder_input_data by one timestep
        decoder_input_data[i, t, target_token_index[char]] = 1.0
        if t > 0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.0
    #decoder_input_data[i, t + 1 :, target_token_index[" "]] = 1.0
    #decoder_target_data[i, t:, target_token_index[" "]] = 1.0
# Out:
# Number of samples: 142000
# Number of unique input tokens: 53
# Number of unique output tokens: 42
# Max sequence length for inputs: 25
# Max sequence length for outputs: 23

# %%
# Define an input sequence and process it.
encoder_inputs = keras.Input(shape=(None, num_encoder_tokens))
encoder = keras.layers.LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)

# We discard `encoder_outputs` and only keep the states.
encoder_states = [state_h, state_c]

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = keras.Input(shape=(None, num_decoder_tokens))

# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_lstm = keras.layers.LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs, initial_state=encoder_states)
decoder_dense = keras.layers.Dense(num_decoder_tokens, activation="softmax")
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
model = keras.Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %%
model.compile(
    optimizer="rmsprop", loss="categorical_crossentropy", metrics=["accuracy"]
)
model.fit(
    [encoder_input_data, decoder_input_data],
    decoder_target_data,
    batch_size=batch_size,
    epochs=epochs,
    validation_split=0.2,
)
# Save model
model.save("s2s")
# Out:
# Epoch 1/100
# 125/125 [==============================] - 15s 97ms/step - loss: 1.0211 - accuracy: 0.7277 - val_loss: 1.0646 - val_accuracy: 0.7426
# Epoch 2/100
# 125/125 [==============================] - 12s 92ms/step - loss: 0.9518 - accuracy: 0.7504 - val_loss: 1.0592 - val_accuracy: 0.7495
# Epoch 3/100
# 125/125 [==============================] - 11s 92ms/step - loss: 0.9171 - accuracy: 0.7587 - val_loss: 1.0909 - val_accuracy: 0.7366
# Epoch 4/100
# 125/125 [==============================] - 12s 93ms/step - loss: 0.8841 - accuracy: 0.7688 - val_loss: 1.1154 - val_accuracy: 0.7331
# Epoch 5/100
# 125/125 [==============================] - 11s 92ms/step - loss: 0.8620 - accuracy: 0.7758 - val_loss: 1.1200 - val_accuracy: 0.7391
# Epoch 6/100
# 125/125 [==============================] - 12s 93ms/step - loss: 0.8351 - accuracy: 0.7854 - val_loss: 1.1040 - val_accuracy: 0.7355
# Epoch 7/100
# 125/125 [==============================] - 12s 97ms/step - loss: 0.8111 - accuracy: 0.7928 - val_loss: 1.1312 - val_accuracy: 0.7436
# Epoch 8/100
# 125/125 [==============================] - 11s 92ms/step - loss: 0.7894 - accuracy: 0.8007 - val_loss: 1.0880 - val_accuracy: 0.7433
# Epoch 9/100
# 125/125 [==============================] - 11s 91ms/step - loss: 0.7723 - accuracy: 0.8058 - val_loss: 1.0983 - val_accuracy: 0.7470
# Epoch 10/100
# 125/125 [==============================] - 12s 95ms/step - loss: 0.7565 - accuracy: 0.8111 - val_loss: 1.1217 - val_accuracy: 0.7448
# Epoch 11/100
# 125/125 [==============================] - 12s 97ms/step - loss: 0.7391 - accuracy: 0.8166 - val_loss: 1.0897 - val_accuracy: 0.7468
# Epoch 12/100
# 125/125 [==============================] - 12s 96ms/step - loss: 0.7238 - accuracy: 0.8214 - val_loss: 1.0942 - val_accuracy: 0.7488
# Epoch 13/100
# 125/125 [==============================] - 12s 97ms/step - loss: 0.7125 - accuracy: 0.8251 - val_loss: 1.1071 - val_accuracy: 0.7503
# Epoch 14/100
# 125/125 [==============================] - 12s 96ms/step - loss: 0.6984 - accuracy: 0.8296 - val_loss: 1.0898 - val_accuracy: 0.7487
# Epoch 15/100
# 125/125 [==============================] - 12s 97ms/step - loss: 0.6844 - accuracy: 0.8349 - val_loss: 1.0704 - val_accuracy: 0.7493
# Epoch 16/100
# 125/125 [==============================] - 12s 97ms/step - loss: 0.6715 - accuracy: 0.8391 - val_loss: 1.0680 - val_accuracy: 0.7458
# Epoch 17/100
# 125/125 [==============================] - 12s 98ms/step - loss: 0.6587 - accuracy: 0.8441 - val_loss: 1.0854 - val_accuracy: 0.7470
# Epoch 18/100
# 125/125 [==============================] - 12s 97ms/step - loss: 0.6487 - accuracy: 0.8479 - val_loss: 1.0495 - val_accuracy: 0.7517
# Epoch 19/100
# 125/125 [==============================] - 12s 95ms/step - loss: 0.6348 - accuracy: 0.8522 - val_loss: 1.0598 - val_accuracy: 0.7478
# Epoch 20/100
# 125/125 [==============================] - 11s 90ms/step - loss: 0.6241 - accuracy: 0.8561 - val_loss: 1.0327 - val_accuracy: 0.7515
# Epoch 21/100
# 125/125 [==============================] - 12s 95ms/step - loss: 0.6118 - accuracy: 0.8604 - val_loss: 1.0538 - val_accuracy: 0.7491
# Epoch 22/100
# 125/125 [==============================] - 12s 95ms/step - loss: 0.6038 - accuracy: 0.8633 - val_loss: 1.0538 - val_accuracy: 0.7510
# Epoch 23/100
# 125/125 [==============================] - 12s 94ms/step - loss: 0.5962 - accuracy: 0.8662 - val_loss: 1.0396 - val_accuracy: 0.7469
# Epoch 24/100
# 125/125 [==============================] - 12s 94ms/step - loss: 0.5836 - accuracy: 0.8707 - val_loss: 1.0292 - val_accuracy: 0.7519
# Epoch 25/100
# 125/125 [==============================] - 12s 95ms/step - loss: 0.5729 - accuracy: 0.8747 - val_loss: 1.0346 - val_accuracy: 0.7544
# Epoch 26/100
# 125/125 [==============================] - 12s 96ms/step - loss: 0.5624 - accuracy: 0.8791 - val_loss: 1.0375 - val_accuracy: 0.7518
# Epoch 27/100
# 125/125 [==============================] - 12s 95ms/step - loss: 0.5545 - accuracy: 0.8822 - val_loss: 1.0306 - val_accuracy: 0.7530
# Epoch 28/100
# 125/125 [==============================] - 12s 94ms/step - loss: 0.5444 - accuracy: 0.8850 - val_loss: 1.0234 - val_accuracy: 0.7532
# Epoch 29/100
# 125/125 [==============================] - 12s 94ms/step - loss: 0.5343 - accuracy: 0.8889 - val_loss: 1.0216 - val_accuracy: 0.7532
# Epoch 30/100
# 125/125 [==============================] - 12s 97ms/step - loss: 0.5264 - accuracy: 0.8923 - val_loss: 1.0284 - val_accuracy: 0.7511
# Epoch 31/100
# 125/125 [==============================] - 12s 96ms/step - loss: 0.5169 - accuracy: 0.8953 - val_loss: 1.0186 - val_accuracy: 0.7537
# Epoch 32/100
# 125/125 [==============================] - 12s 96ms/step - loss: 0.5095 - accuracy: 0.8983 - val_loss: 1.0101 - val_accuracy: 0.7553
# Epoch 33/100
# 125/125 [==============================] - 12s 96ms/step - loss: 0.5009 - accuracy: 0.9011 - val_loss: 1.0081 - val_accuracy: 0.7560
# Epoch 34/100
# 125/125 [==============================] - 12s 95ms/step - loss: 0.4939 - accuracy: 0.9032 - val_loss: 1.0152 - val_accuracy: 0.7557
# Epoch 35/100
# 125/125 [==============================] - 12s 94ms/step - loss: 0.4845 - accuracy: 0.9066 - val_loss: 0.9950 - val_accuracy: 0.7574
# Epoch 36/100
# 125/125 [==============================] - 13s 102ms/step - loss: 0.4780 - accuracy: 0.9082 - val_loss: 1.0033 - val_accuracy: 0.7567
# Epoch 37/100
# 125/125 [==============================] - 12s 97ms/step - loss: 0.4702 - accuracy: 0.9104 - val_loss: 1.0045 - val_accuracy: 0.7564
# Epoch 38/100
# 125/125 [==============================] - 12s 97ms/step - loss: 0.4634 - accuracy: 0.9118 - val_loss: 0.9950 - val_accuracy: 0.7632
# Epoch 39/100
# 125/125 [==============================] - 12s 96ms/step - loss: 0.4570 - accuracy: 0.9140 - val_loss: 0.9995 - val_accuracy: 0.7593
# Epoch 40/100
# 125/125 [==============================] - 12s 97ms/step - loss: 0.4495 - accuracy: 0.9164 - val_loss: 0.9924 - val_accuracy: 0.7586
# Epoch 41/100
# 125/125 [==============================] - 12s 96ms/step - loss: 0.4450 - accuracy: 0.9170 - val_loss: 0.9954 - val_accuracy: 0.7606
# Epoch 42/100
# 125/125 [==============================] - 12s 96ms/step - loss: 0.4392 - accuracy: 0.9190 - val_loss: 0.9958 - val_accuracy: 0.7585
# Epoch 43/100
# 125/125 [==============================] - 12s 97ms/step - loss: 0.4315 - accuracy: 0.9206 - val_loss: 0.9959 - val_accuracy: 0.7580
# Epoch 44/100
# 125/125 [==============================] - 12s 97ms/step - loss: 0.4275 - accuracy: 0.9216 - val_loss: 0.9938 - val_accuracy: 0.7596
# Epoch 45/100
# 125/125 [==============================] - 12s 96ms/step - loss: 0.4232 - accuracy: 0.9220 - val_loss: 0.9974 - val_accuracy: 0.7568
# Epoch 46/100
# 125/125 [==============================] - 12s 97ms/step - loss: 0.4164 - accuracy: 0.9233 - val_loss: 0.9717 - val_accuracy: 0.7658
# Epoch 47/100
# 125/125 [==============================] - 12s 97ms/step - loss: 0.4113 - accuracy: 0.9241 - val_loss: 0.9860 - val_accuracy: 0.7624
# Epoch 48/100
# 125/125 [==============================] - 12s 95ms/step - loss: 0.4083 - accuracy: 0.9248 - val_loss: 1.0011 - val_accuracy: 0.7570
# Epoch 49/100
# 125/125 [==============================] - 12s 96ms/step - loss: 0.4037 - accuracy: 0.9256 - val_loss: 0.9879 - val_accuracy: 0.7608
# Epoch 50/100
# 125/125 [==============================] - 12s 96ms/step - loss: 0.3965 - accuracy: 0.9272 - val_loss: 0.9835 - val_accuracy: 0.7616
# Epoch 51/100
# 125/125 [==============================] - 12s 96ms/step - loss: 0.3928 - accuracy: 0.9284 - val_loss: 0.9950 - val_accuracy: 0.7597
# Epoch 52/100
# 125/125 [==============================] - 12s 95ms/step - loss: 0.3883 - accuracy: 0.9294 - val_loss: 1.0082 - val_accuracy: 0.7578
# Epoch 53/100
# 125/125 [==============================] - 12s 95ms/step - loss: 0.3838 - accuracy: 0.9305 - val_loss: 0.9680 - val_accuracy: 0.7645
# Epoch 54/100
# 125/125 [==============================] - 12s 95ms/step - loss: 0.3806 - accuracy: 0.9307 - val_loss: 0.9855 - val_accuracy: 0.7653
# Epoch 55/100
# 125/125 [==============================] - 12s 96ms/step - loss: 0.3760 - accuracy: 0.9321 - val_loss: 0.9910 - val_accuracy: 0.7600
# Epoch 56/100
# 125/125 [==============================] - 12s 96ms/step - loss: 0.3727 - accuracy: 0.9324 - val_loss: 0.9864 - val_accuracy: 0.7594
# Epoch 57/100
# 125/125 [==============================] - 12s 96ms/step - loss: 0.3687 - accuracy: 0.9329 - val_loss: 0.9819 - val_accuracy: 0.7639
# Epoch 58/100
# 125/125 [==============================] - 12s 98ms/step - loss: 0.3649 - accuracy: 0.9340 - val_loss: 0.9874 - val_accuracy: 0.7574
# Epoch 59/100
# 125/125 [==============================] - 12s 97ms/step - loss: 0.3579 - accuracy: 0.9356 - val_loss: 1.0000 - val_accuracy: 0.7579
# Epoch 60/100
# 125/125 [==============================] - 12s 97ms/step - loss: 0.3523 - accuracy: 0.9365 - val_loss: 0.9915 - val_accuracy: 0.7608
# Epoch 61/100
# 125/125 [==============================] - 12s 96ms/step - loss: 0.3506 - accuracy: 0.9360 - val_loss: 0.9807 - val_accuracy: 0.7636
# Epoch 62/100
# 125/125 [==============================] - 12s 99ms/step - loss: 0.3440 - accuracy: 0.9374 - val_loss: 0.9633 - val_accuracy: 0.7678
# Epoch 63/100
# 125/125 [==============================] - 12s 98ms/step - loss: 0.3400 - accuracy: 0.9374 - val_loss: 0.9867 - val_accuracy: 0.7637
# Epoch 64/100
# 125/125 [==============================] - 12s 98ms/step - loss: 0.3382 - accuracy: 0.9376 - val_loss: 0.9811 - val_accuracy: 0.7641
# Epoch 65/100
# 125/125 [==============================] - 12s 97ms/step - loss: 0.3335 - accuracy: 0.9384 - val_loss: 0.9703 - val_accuracy: 0.7640
# Epoch 66/100
# 125/125 [==============================] - 12s 98ms/step - loss: 0.3307 - accuracy: 0.9392 - val_loss: 0.9904 - val_accuracy: 0.7643
# Epoch 67/100
# 125/125 [==============================] - 12s 97ms/step - loss: 0.3218 - accuracy: 0.9414 - val_loss: 0.9675 - val_accuracy: 0.7618
# Epoch 68/100
# 125/125 [==============================] - 12s 98ms/step - loss: 0.3239 - accuracy: 0.9408 - val_loss: 0.9687 - val_accuracy: 0.7650
# Epoch 69/100
# 125/125 [==============================] - 12s 98ms/step - loss: 0.3195 - accuracy: 0.9410 - val_loss: 0.9719 - val_accuracy: 0.7664
# Epoch 70/100
# 125/125 [==============================] - 12s 96ms/step - loss: 0.3127 - accuracy: 0.9425 - val_loss: 0.9653 - val_accuracy: 0.7678
# Epoch 71/100
# 125/125 [==============================] - 12s 95ms/step - loss: 0.3108 - accuracy: 0.9428 - val_loss: 0.9530 - val_accuracy: 0.7692
# Epoch 72/100
# 125/125 [==============================] - 12s 94ms/step - loss: 0.3076 - accuracy: 0.9436 - val_loss: 0.9575 - val_accuracy: 0.7653
# Epoch 73/100
# 125/125 [==============================] - 12s 95ms/step - loss: 0.3071 - accuracy: 0.9433 - val_loss: 0.9545 - val_accuracy: 0.7681
# Epoch 74/100
# 125/125 [==============================] - 12s 96ms/step - loss: 0.3027 - accuracy: 0.9447 - val_loss: 0.9618 - val_accuracy: 0.7650
# Epoch 75/100
# 125/125 [==============================] - 12s 94ms/step - loss: 0.2973 - accuracy: 0.9454 - val_loss: 0.9692 - val_accuracy: 0.7612
# Epoch 76/100
# 125/125 [==============================] - 12s 94ms/step - loss: 0.2938 - accuracy: 0.9455 - val_loss: 0.9841 - val_accuracy: 0.7591
# Epoch 77/100
# 125/125 [==============================] - 12s 94ms/step - loss: 0.2887 - accuracy: 0.9473 - val_loss: 0.9603 - val_accuracy: 0.7627
# Epoch 78/100
# 125/125 [==============================] - 12s 96ms/step - loss: 0.2897 - accuracy: 0.9466 - val_loss: 0.9413 - val_accuracy: 0.7706
# Epoch 79/100
# 125/125 [==============================] - 12s 96ms/step - loss: 0.2828 - accuracy: 0.9481 - val_loss: 0.9408 - val_accuracy: 0.7676
# Epoch 80/100
# 125/125 [==============================] - 12s 98ms/step - loss: 0.2816 - accuracy: 0.9477 - val_loss: 0.9524 - val_accuracy: 0.7689
# Epoch 81/100
# 125/125 [==============================] - 12s 96ms/step - loss: 0.2770 - accuracy: 0.9491 - val_loss: 0.9533 - val_accuracy: 0.7699
# Epoch 82/100
# 125/125 [==============================] - 12s 95ms/step - loss: 0.2765 - accuracy: 0.9491 - val_loss: 0.9669 - val_accuracy: 0.7641
# Epoch 83/100
# 125/125 [==============================] - 11s 91ms/step - loss: 0.2736 - accuracy: 0.9493 - val_loss: 0.9470 - val_accuracy: 0.7696
# Epoch 84/100
# 125/125 [==============================] - 11s 89ms/step - loss: 0.2720 - accuracy: 0.9497 - val_loss: 0.9651 - val_accuracy: 0.7663
# Epoch 85/100
# 125/125 [==============================] - 11s 88ms/step - loss: 0.2694 - accuracy: 0.9504 - val_loss: 0.9696 - val_accuracy: 0.7642
# Epoch 86/100
# 125/125 [==============================] - 11s 88ms/step - loss: 0.2658 - accuracy: 0.9512 - val_loss: 0.9436 - val_accuracy: 0.7691
# Epoch 87/100
# 125/125 [==============================] - 11s 87ms/step - loss: 0.2632 - accuracy: 0.9519 - val_loss: 0.9801 - val_accuracy: 0.7620
# Epoch 88/100
# 125/125 [==============================] - 12s 93ms/step - loss: 0.2588 - accuracy: 0.9527 - val_loss: 0.9817 - val_accuracy: 0.7618
# Epoch 89/100
# 125/125 [==============================] - 12s 95ms/step - loss: 0.2570 - accuracy: 0.9529 - val_loss: 0.9562 - val_accuracy: 0.7663
# Epoch 90/100
# 125/125 [==============================] - 12s 97ms/step - loss: 0.2619 - accuracy: 0.9513 - val_loss: 0.9596 - val_accuracy: 0.7655
# Epoch 91/100
# 125/125 [==============================] - 12s 96ms/step - loss: 0.2534 - accuracy: 0.9534 - val_loss: 0.9577 - val_accuracy: 0.7683
# Epoch 92/100
# 125/125 [==============================] - 12s 94ms/step - loss: 0.2509 - accuracy: 0.9538 - val_loss: 0.9699 - val_accuracy: 0.7643
# Epoch 93/100
# 125/125 [==============================] - 12s 94ms/step - loss: 0.2467 - accuracy: 0.9551 - val_loss: 0.9548 - val_accuracy: 0.7682
# Epoch 94/100
# 125/125 [==============================] - 12s 93ms/step - loss: 0.2454 - accuracy: 0.9548 - val_loss: 0.9542 - val_accuracy: 0.7682
# Epoch 95/100
# 125/125 [==============================] - 12s 93ms/step - loss: 0.2431 - accuracy: 0.9554 - val_loss: 0.9693 - val_accuracy: 0.7659
# Epoch 96/100
# 125/125 [==============================] - 12s 96ms/step - loss: 0.2393 - accuracy: 0.9561 - val_loss: 0.9508 - val_accuracy: 0.7716
# Epoch 97/100
# 125/125 [==============================] - 12s 93ms/step - loss: 0.2393 - accuracy: 0.9560 - val_loss: 0.9674 - val_accuracy: 0.7687
# Epoch 98/100
# 125/125 [==============================] - 12s 94ms/step - loss: 0.2378 - accuracy: 0.9569 - val_loss: 0.9537 - val_accuracy: 0.7671
# Epoch 99/100
# 125/125 [==============================] - 12s 93ms/step - loss: 0.2347 - accuracy: 0.9572 - val_loss: 0.9582 - val_accuracy: 0.7698
# Epoch 100/100
# 125/125 [==============================] - 12s 92ms/step - loss: 0.2294 - accuracy: 0.9586 - val_loss: 0.9706 - val_accuracy: 0.7667
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: s2s/assets
# INFO:tensorflow:Assets written to: s2s/assets

# %%
# Define sampling models
# Restore the model and construct the encoder and decoder.
model = keras.models.load_model("s2s")

encoder_inputs = model.input[0]  # input_1
encoder_outputs, state_h_enc, state_c_enc = model.layers[2].output  # lstm_1
encoder_states = [state_h_enc, state_c_enc]
encoder_model = keras.Model(encoder_inputs, encoder_states)

decoder_inputs = model.input[1]  # input_2
decoder_state_input_h = keras.Input(shape=(latent_dim,))
decoder_state_input_c = keras.Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_lstm = model.layers[3]
decoder_outputs, state_h_dec, state_c_dec = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs
)
decoder_states = [state_h_dec, state_c_dec]
decoder_dense = model.layers[4]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = keras.Model(
    [decoder_inputs] + decoder_states_inputs, [decoder_outputs] + decoder_states
)

# Reverse-lookup token index to decode sequences back to
# something readable.
reverse_input_char_index = dict((i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict((i, char) for char, i in target_token_index.items())


def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0, target_token_index[","]] = 1.0

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ""
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        if sampled_char == "\n" or len(decoded_sentence) > max_decoder_seq_length:
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.0

        # Update states
        states_value = [h, c]
    return decoded_sentence

# %%
for seq_index in range(20):
    # Take one sequence (part of the training set)
    # for trying out decoding.
    input_seq = encoder_input_data[seq_index : seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print("-")
    print("Input sentence:", input_texts[seq_index])
    print("Decoded sentence:", decoded_sentence)
# Out:
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 298ms/step
# 1/1 [==============================] - 0s 19ms/step
# -
# Input sentence: a
# Decoded sentence: E
#
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# -
# Input sentence: a
# Decoded sentence: E
#
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# -
# Input sentence: a
# Decoded sentence: E
#
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# -
# Input sentence: a capella
# Decoded sentence: akapll
#
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# -
# Input sentence: a cappella
# Decoded sentence: akaple
#
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# -
# Input sentence: a contrario
# Decoded sentence: akutRaRj
#
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# -
# Input sentence: a fortiori
# Decoded sentence: abORtER
#
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# -
# Input sentence: a giorno
# Decoded sentence: aZ°nj§
#
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# -
# Input sentence: a jeun
# Decoded sentence: anE
#
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# -
# Input sentence: a l'instar
# Decoded sentence: al@stn
#
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# -
# Input sentence: a posteriori
# Decoded sentence: apst@djonE
#
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# -
# Input sentence: a priori
# Decoded sentence: apRiti
#
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# -
# Input sentence: a priori
# Decoded sentence: apRiti
#
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# -
# Input sentence: aa
# Decoded sentence: E
#
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# -
# Input sentence: ab absurdo
# Decoded sentence: abaz°RER
#
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# -
# Input sentence: ab initio
# Decoded sentence: abinisj§
#
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# -
# Input sentence: ab ovo
# Decoded sentence: abone
#
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# -
# Input sentence: abaca
# Decoded sentence: aba
#
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# -
# Input sentence: abaissa
# Decoded sentence: abEsE
#
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# -
# Input sentence: abaissai
# Decoded sentence: abEse
